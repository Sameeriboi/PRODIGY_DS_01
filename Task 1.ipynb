# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = {'Name' : ['sameer', 'rahul', 'dishank', 'anoushka', 'anusha', 'hetal','hazel'],
        'Gender': ['Male', 'Male', 'Male', 'Female', 'Female', 'Female', 'Female'],
        'Age': [20, 33, 54, 24, 46, 30, 25]}

df = pd.DataFrame(data)

# %%
#Graph for Gender Distrbution
gender_counts = df['Gender'].value_counts()

plt.bar(gender_counts.index, gender_counts.values, color=['blue', 'pink'])
plt.title('Gender Distribution in Population')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Graph for Age Distrbution
age_counts = df['Age'].value_counts()
age_counts = age_counts.sort_index()

plt.hist(df['Age'], bins=5, edgecolor='black', color='green')
plt.title('Age Distribution in Population')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
